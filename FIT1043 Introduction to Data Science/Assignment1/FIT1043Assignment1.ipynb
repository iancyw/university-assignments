# %% [markdown]
# # FIT1043 Introduction to Data Science Assignment 1
# Ian WONG
# <br>
# **Student ID:** 30612616
# ---
# ## Importing Libraries
# The first library we will be importing is **pandas**, which is used to create data structures called *DataFrames*. These dataframes allow use to manage and manipulate data more easily.
#
# We will also be importing **matplotlib.pyplot**, which is used to plot and visualise data in Python. This can also be done later on, if you prefer to order your code sequentially.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading datasets
# Using the `read_csv` command from **pandas**, we are reading in the datasets from the data folder and assigning them to:
# - `vaccinations` for 'Country-Vaccinations.csv'
# - `gdp` for '2020-GDP.csv'
# - `pop` for '2020-Population.csv'

# %%
vaccinations = pd.read_csv('data/Country-Vaccinations.csv')
gdp = pd.read_csv('data/2020-GDP.csv')
pop = pd.read_csv('data/2020-Population.csv')

# %% [markdown]
# To make sure we have read the data in properly, we will be checking the head, tail, and a random sample of each dataset:

# %%
vaccinations.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
vaccinations.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 36731  Zimbabwe      ZWE  2021-08-04           2604265.0          1740598.0
# 36732  Zimbabwe      ZWE  2021-08-05           2701095.0          1780541.0
# 36733  Zimbabwe      ZWE  2021-08-06           2784270.0          1817598.0
# 36734  Zimbabwe      ZWE  2021-08-07           2853668.0          1851407.0
# 36735  Zimbabwe      ZWE  2021-08-08           2886822.0          1864204.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 36731                 863667.0                 63710.0             46978.0
# 36732                 920554.0                 96830.0             53866.0
# 36733                 966672.0                 83175.0             58416.0
# 36734                1002261.0                 69398.0             62880.0
# 36735                1022618.0                 33154.0             64783.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 36731                           17.52                          11.71
# 36732                           18.17                          11.98
# 36733                           18.73                          12.23
# 36734                           19.20                          12.46
# 36735                           19.42                          12.54
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 36731                                 5.81                          3161.0
# 36732                                 6.19                          3624.0
# 36733                                 6.50                          3930.0
# 36734                                 6.74                          4231.0
# 36735                                 6.88                          4359.0
#
#                                     vaccines         source_name  \
# 36731  Sinopharm/Beijing, Sinovac, Sputnik V  Ministry of Health
# 36732  Sinopharm/Beijing, Sinovac, Sputnik V  Ministry of Health
# 36733  Sinopharm/Beijing, Sinovac, Sputnik V  Ministry of Health
# 36734  Sinopharm/Beijing, Sinovac, Sputnik V  Ministry of Health
# 36735  Sinopharm/Beijing, Sinovac, Sputnik V  Ministry of Health
#
#                                           source_website
# 36731  https://twitter.com/MoHCCZim/status/1424470300...
# 36732  https://twitter.com/MoHCCZim/status/1424470300...
# 36733  https://twitter.com/MoHCCZim/status/1424470300...
# 36734  https://twitter.com/MoHCCZim/status/1424470300...
# 36735  https://twitter.com/MoHCCZim/status/1424470300...

# %%
vaccinations.sample(5)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 10686  Ethiopia      ETH  2021-04-13                 NaN                NaN
# 11992    Gambia      GMB  2021-03-13                 NaN                NaN
# 14240  Honduras      HND  2021-03-19             37317.0            37317.0
# 33168     Timor      TLS  2021-05-10                 NaN                NaN
# 27657    Russia      RUS  2021-07-01          40875355.0         23352344.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10686                      NaN                     NaN             32074.0
# 11992                      NaN                     NaN               281.0
# 14240                      NaN                     NaN              4474.0
# 33168                      NaN                     NaN              1236.0
# 27657               17523011.0                847411.0            557869.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10686                             NaN                            NaN
# 11992                             NaN                            NaN
# 14240                            0.38                           0.38
# 33168                             NaN                            NaN
# 27657                           28.01                          16.00
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 10686                                  NaN                           279.0
# 11992                                  NaN                           116.0
# 14240                                  NaN                           452.0
# 33168                                  NaN                           937.0
# 27657                                12.01                          3823.0
#
#                                                 vaccines  \
# 10686                                 Oxford/AstraZeneca
# 11992              Oxford/AstraZeneca, Sinopharm/Beijing
# 14240  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 33168                        Oxford/AstraZeneca, Sinovac
# 27657                            EpiVacCorona, Sputnik V
#
#                                              source_name  \
# 10686                                 Ministry of Health
# 11992  Africa Centres for Disease Control and Prevention
# 14240                          World Health Organization
# 33168                          World Health Organization
# 27657  Official data from local governments via gogov.ru
#
#                                           source_website
# 10686  https://twitter.com/FMoHealth/status/142481930...
# 11992        https://africacdc.org/covid-19-vaccination/
# 14240                      http://www.salud.gob.hn/site/
# 33168                           https://covid19.who.int/
# 27657            https://gogov.ru/articles/covid-v-stats

# %%
gdp.head()
# Out:
#   Unnamed: 0 Gross domestic product 2020  Unnamed: 2     Unnamed: 3  \
# 0        NaN                         NaN         NaN            NaN
# 1        NaN                         NaN         NaN            NaN
# 2        NaN                     Ranking         NaN        Economy
# 3        NaN                         NaN         NaN            NaN
# 4        USA                           1         NaN  United States
#
#      Unnamed: 4 Unnamed: 5
# 0           NaN        NaN
# 1  (millions of        NaN
# 2   US dollars)        NaN
# 3           NaN        NaN
# 4   20,936,600         NaN

# %%
gdp.tail()
# Out:
#     Unnamed: 0 Gross domestic product 2020  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 324        NaN                         NaN         NaN        NaN        NaN
# 325        NaN                         NaN         NaN        NaN        NaN
# 326        NaN                         NaN         NaN        NaN        NaN
# 327        NaN                         NaN         NaN        NaN        NaN
# 328        NaN                         NaN         NaN        NaN        NaN
#
#     Unnamed: 5
# 324        NaN
# 325        NaN
# 326        NaN
# 327        NaN
# 328        NaN

# %%
gdp.sample(5)
# Out:
#     Unnamed: 0 Gross domestic product 2020  Unnamed: 2    Unnamed: 3  \
# 201        TON                         198         NaN         Tonga
# 68         ECU                          65         NaN       Ecuador
# 100        NPL                          97         NaN         Nepal
# 296        NaN                         NaN         NaN           NaN
# 91         TKM                          88         NaN  Turkmenistan
#
#     Unnamed: 4 Unnamed: 5
# 201       512         NaN
# 68     98,808         NaN
# 100    33,657         NaN
# 296        NaN        NaN
# 91     45,231         NaN

# %%
pop.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN        NaN        NaN
# 2                  NaN        NaN        NaN        NaN        NaN        NaN
# 3       United Nations        NaN        NaN        NaN        NaN        NaN
# 4  Population Division        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 68 Unnamed: 69  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#   Unnamed: 70 Unnamed: 71 Unnamed: 72 Unnamed: 73 Unnamed: 74 Unnamed: 75  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 76 Unnamed: 77
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 78 columns]

# %%
pop.tail()
# Out:
#     Unnamed: 0 Unnamed: 1                 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 300        285  Estimates                    Bermuda         14         60
# 301        286  Estimates                     Canada        NaN        124
# 302        287  Estimates                  Greenland         26        304
# 303        288  Estimates  Saint Pierre and Miquelon          2        666
# 304        289  Estimates   United States of America         35        840
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 300  Country/Area        918         37         38         38  ...
# 301  Country/Area        918     13 733     14 078     14 445  ...
# 302  Country/Area        918         23         23         24  ...
# 303  Country/Area        918          5          5          5  ...
# 304  Country/Area        918    158 804    160 872    163 266  ...
#
#     Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72 Unnamed: 73  \
# 300          65          65          64          64          64          63
# 301      34 539      34 922      35 297      35 664      36 027      36 383
# 302          57          56          56          56          56          56
# 303           6           6           6           6           6           6
# 304     311 584     314 044     316 401     318 673     320 878     323 016
#
#     Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77
# 300          63          63          63          62
# 301      36 732      37 075      37 411      37 742
# 302          56          57          57          57
# 303           6           6           6           6
# 304     325 085     327 096     329 065     331 003
#
# [5 rows x 78 columns]

# %%
pop.sample(5)
# Out:
#     Unnamed: 0 Unnamed: 1                        Unnamed: 2 Unnamed: 3  \
# 138        123  Estimates                             Nepal        NaN
# 155        140  Estimates  Lao People's Democratic Republic        NaN
# 120        105  Estimates              Syrian Arab Republic        NaN
# 66          51  Estimates                              Chad        NaN
# 225        210  Estimates                   Solomon Islands        NaN
#
#     Unnamed: 4    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 138        524  Country/Area       5501      8 483      8 664      8 835  ...
# 155        418  Country/Area        920      1 683      1 723      1 764  ...
# 120        760  Country/Area        922      3 413      3 499      3 591  ...
# 66         148  Country/Area        911      2 502      2 544      2 589  ...
# 225         90  Country/Area        928         90         92         94  ...
#
#     Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72 Unnamed: 73  \
# 138      27 041      26 989      26 917      26 906      27 015      27 263
# 155       6 348       6 445       6 541       6 640       6 741       6 846
# 120      21 082      20 439      19 578      18 711      17 997      17 466
# 66       12 361      12 785      13 220      13 664      14 111      14 562
# 225         542         556         571         587         603         619
#
#     Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77
# 138      27 633      28 096      28 609      29 137
# 155       6 953       7 061       7 169       7 276
# 120      17 096      16 945      17 070      17 501
# 66       15 017      15 478      15 947      16 426
# 225         636         653         670         687
#
# [5 rows x 78 columns]

# %% [markdown]
# ## Data Wrangling
# In this section, we will be sub-setting the necessary data that is required.
# ### Vaccination DataFrame
# For the vaccination related DataFrame, we are keeping the columns:
# - `country`,
# - `people_fully_vaccinated`,
# - `total_vaccinations` (as an aggregation of `daily_vaccinations`),
# - and `vaccines`
#
# ---
#
# Using `.groupby()` and `.agg()`, we are grouping the dataframe by country and finding:
# - max of people fully vaccinated
# - sum of daily vaccinations
# - vaccines available in a country

# %%
fun = {'people_fully_vaccinated':'max',
       'daily_vaccinations':'sum',
       'vaccines':'max'}

# %%
vaccinations = vaccinations.groupby(['country']).agg(fun)
vaccinations
# Out:
#                    people_fully_vaccinated  daily_vaccinations  \
# country
# Afghanistan                       219159.0           1649463.0
# Albania                           553482.0           1237306.0
# Algeria                           724812.0           4075025.0
# Andorra                            33904.0             76689.0
# Angola                            722610.0           1690469.0
# ...                                    ...                 ...
# Wales                            2115477.0           4396339.0
# Wallis and Futuna                   4659.0              8937.0
# Yemen                              13322.0            302943.0
# Zambia                            193603.0            475566.0
# Zimbabwe                         1022618.0           2693298.0
#
#                                                             vaccines
# country
# Afghanistan        Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Albania            Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# Algeria            Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# Andorra                          Oxford/AstraZeneca, Pfizer/BioNTech
# Angola                                            Oxford/AstraZeneca
# ...                                                              ...
# Wales                   Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# Wallis and Futuna                                 Oxford/AstraZeneca
# Yemen                                             Oxford/AstraZeneca
# Zambia                         Oxford/AstraZeneca, Sinopharm/Beijing
# Zimbabwe                       Sinopharm/Beijing, Sinovac, Sputnik V
#
# [222 rows x 3 columns]

# %% [markdown]
# Using `.rename()`, we are renaming the columns into more appropriate and formatted labels:

# %%
vaccinations.rename(
    columns = {'people_fully_vaccinated':'People Fully Vaccinated',
               'daily_vaccinations':'Total Vaccinations',
               'vaccines':'Vaccines Available'},
    inplace = True
)
vaccinations
# Out:
#                    People Fully Vaccinated  Total Vaccinations  \
# country
# Afghanistan                       219159.0           1649463.0
# Albania                           553482.0           1237306.0
# Algeria                           724812.0           4075025.0
# Andorra                            33904.0             76689.0
# Angola                            722610.0           1690469.0
# ...                                    ...                 ...
# Wales                            2115477.0           4396339.0
# Wallis and Futuna                   4659.0              8937.0
# Yemen                              13322.0            302943.0
# Zambia                            193603.0            475566.0
# Zimbabwe                         1022618.0           2693298.0
#
#                                                   Vaccines Available
# country
# Afghanistan        Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Albania            Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# Algeria            Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# Andorra                          Oxford/AstraZeneca, Pfizer/BioNTech
# Angola                                            Oxford/AstraZeneca
# ...                                                              ...
# Wales                   Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# Wallis and Futuna                                 Oxford/AstraZeneca
# Yemen                                             Oxford/AstraZeneca
# Zambia                         Oxford/AstraZeneca, Sinopharm/Beijing
# Zimbabwe                       Sinopharm/Beijing, Sinovac, Sputnik V
#
# [222 rows x 3 columns]

# %% [markdown]
# To flatten the columns, we use `.reset_index()`:

# %%
vaccinations = vaccinations.reset_index()
vaccinations
# Out:
#                country  People Fully Vaccinated  Total Vaccinations  \
# 0          Afghanistan                 219159.0           1649463.0
# 1              Albania                 553482.0           1237306.0
# 2              Algeria                 724812.0           4075025.0
# 3              Andorra                  33904.0             76689.0
# 4               Angola                 722610.0           1690469.0
# ..                 ...                      ...                 ...
# 217              Wales                2115477.0           4396339.0
# 218  Wallis and Futuna                   4659.0              8937.0
# 219              Yemen                  13322.0            302943.0
# 220             Zambia                 193603.0            475566.0
# 221           Zimbabwe                1022618.0           2693298.0
#
#                                     Vaccines Available
# 0    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 2    Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech
# 4                                   Oxford/AstraZeneca
# ..                                                 ...
# 217       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 218                                 Oxford/AstraZeneca
# 219                                 Oxford/AstraZeneca
# 220              Oxford/AstraZeneca, Sinopharm/Beijing
# 221              Sinopharm/Beijing, Sinovac, Sputnik V
#
# [222 rows x 4 columns]

# %% [markdown]
# Check that we didn't drop any columns:

# %%
vaccinations.columns
# Out:
# Index(['country', 'People Fully Vaccinated', 'Total Vaccinations',
#        'Vaccines Available'],
#       dtype='object')

# %% [markdown]
# Use `.rename()` to format the column name for countries:

# %%
vaccinations.rename(columns = {'country':'Country'},inplace = True)
vaccinations
# Out:
#                Country  People Fully Vaccinated  Total Vaccinations  \
# 0          Afghanistan                 219159.0           1649463.0
# 1              Albania                 553482.0           1237306.0
# 2              Algeria                 724812.0           4075025.0
# 3              Andorra                  33904.0             76689.0
# 4               Angola                 722610.0           1690469.0
# ..                 ...                      ...                 ...
# 217              Wales                2115477.0           4396339.0
# 218  Wallis and Futuna                   4659.0              8937.0
# 219              Yemen                  13322.0            302943.0
# 220             Zambia                 193603.0            475566.0
# 221           Zimbabwe                1022618.0           2693298.0
#
#                                     Vaccines Available
# 0    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 2    Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech
# 4                                   Oxford/AstraZeneca
# ..                                                 ...
# 217       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 218                                 Oxford/AstraZeneca
# 219                                 Oxford/AstraZeneca
# 220              Oxford/AstraZeneca, Sinopharm/Beijing
# 221              Sinopharm/Beijing, Sinovac, Sputnik V
#
# [222 rows x 4 columns]

# %% [markdown]
# ### GDP DataFrame
#
# For the GDP DataFrame, we are keeping the GDP values for each country.
#
# ---
#
# First, by looking at the structure of the GDP DataFrame below, we can determine that the column headings are down below on index 2, and the data starts on index 4.
#
# Therefore, we slice the data and rename to format the data:

# %%
gdp.head()
# Out:
#   Unnamed: 0 Gross domestic product 2020  Unnamed: 2     Unnamed: 3  \
# 0        NaN                         NaN         NaN            NaN
# 1        NaN                         NaN         NaN            NaN
# 2        NaN                     Ranking         NaN        Economy
# 3        NaN                         NaN         NaN            NaN
# 4        USA                           1         NaN  United States
#
#      Unnamed: 4 Unnamed: 5
# 0           NaN        NaN
# 1  (millions of        NaN
# 2   US dollars)        NaN
# 3           NaN        NaN
# 4   20,936,600         NaN

# %% [markdown]
# Slicing the data from index 4:

# %%
gdp = gdp[4:]
gdp
# Out:
#     Unnamed: 0 Gross domestic product 2020  Unnamed: 2      Unnamed: 3  \
# 4          USA                           1         NaN   United States
# 5          CHN                           2         NaN           China
# 6          JPN                           3         NaN           Japan
# 7          DEU                           4         NaN         Germany
# 8          GBR                           5         NaN  United Kingdom
# ..         ...                         ...         ...             ...
# 324        NaN                         NaN         NaN             NaN
# 325        NaN                         NaN         NaN             NaN
# 326        NaN                         NaN         NaN             NaN
# 327        NaN                         NaN         NaN             NaN
# 328        NaN                         NaN         NaN             NaN
#
#        Unnamed: 4 Unnamed: 5
# 4     20,936,600         NaN
# 5     14,722,731         NaN
# 6      5,064,873         NaN
# 7      3,806,060         NaN
# 8      2,707,744         NaN
# ..            ...        ...
# 324           NaN        NaN
# 325           NaN        NaN
# 326           NaN        NaN
# 327           NaN        NaN
# 328           NaN        NaN
#
# [325 rows x 6 columns]

# %% [markdown]
# Using `.loc`, we keep certain columns:

# %%
gdp = gdp.loc[:, ('Unnamed: 3', 'Unnamed: 4')]
gdp
# Out:
#          Unnamed: 3    Unnamed: 4
# 4     United States   20,936,600
# 5             China   14,722,731
# 6             Japan    5,064,873
# 7           Germany    3,806,060
# 8    United Kingdom    2,707,744
# ..              ...           ...
# 324             NaN           NaN
# 325             NaN           NaN
# 326             NaN           NaN
# 327             NaN           NaN
# 328             NaN           NaN
#
# [325 rows x 2 columns]

# %% [markdown]
# Renaming the rows from to `Country` and `GDP`:

# %%
gdp.rename(
    columns = {'Unnamed: 3': 'Country',
               'Unnamed: 4': 'GDP'},
    inplace = True
)
gdp
# Out:
#             Country           GDP
# 4     United States   20,936,600
# 5             China   14,722,731
# 6             Japan    5,064,873
# 7           Germany    3,806,060
# 8    United Kingdom    2,707,744
# ..              ...           ...
# 324             NaN           NaN
# 325             NaN           NaN
# 326             NaN           NaN
# 327             NaN           NaN
# 328             NaN           NaN
#
# [325 rows x 2 columns]

# %% [markdown]
# Dropping rows with `NaN` values and resetting the index:

# %%
gdp = gdp.dropna()
gdp = gdp.reset_index().drop(columns = ['index'])
gdp
# Out:
#                  Country           GDP
# 0          United States   20,936,600
# 1                  China   14,722,731
# 2                  Japan    5,064,873
# 3                Germany    3,806,060
# 4         United Kingdom    2,707,744
# ..                   ...           ...
# 224   Sub-Saharan Africa    1,685,632
# 225           Low income      546,661
# 226  Lower middle income    7,328,774
# 227  Upper middle income   23,630,843
# 228          High income   53,255,167
#
# [229 rows x 2 columns]

# %% [markdown]
# ### Population DataFrame
#
# For the population dataframe, we are keeping the population values for each country as of 2020.
#
# ---
#
# By observing the first 20 indexes of the pop dataframe, we can see that the headings start on index 15 and the data starts on index 16.
#
# Therefore, we slice the data from index 16 onwards and rename the headers:

# %%
pop.head(20)
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                      United Nations        NaN
# 4                                 Population Division        NaN
# 5           Department of Economic and Social Affairs        NaN
# 6                                                 NaN        NaN
# 7                     World Population Prospects 2019        NaN
# 8   File POP/1-1: Total population (both sexes com...        NaN
# 9                              Estimates, 1950 - 2020        NaN
# 10                      POP/DB/WPP/Rev.2019/POP/F01-1        NaN
# 11  © August 2019 by United Nations, made availabl...        NaN
# 12  Suggested citation: United Nations, Department...        NaN
# 13                                                NaN        NaN
# 14                                                NaN        NaN
# 15                                              Index    Variant
# 16                                                  1  Estimates
# 17                                                  2  Estimates
# 18                                                  3  Estimates
# 19                                                  4  Estimates
#
#                               Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0                                    NaN        NaN           NaN
# 1                                    NaN        NaN           NaN
# 2                                    NaN        NaN           NaN
# 3                                    NaN        NaN           NaN
# 4                                    NaN        NaN           NaN
# 5                                    NaN        NaN           NaN
# 6                                    NaN        NaN           NaN
# 7                                    NaN        NaN           NaN
# 8                                    NaN        NaN           NaN
# 9                                    NaN        NaN           NaN
# 10                                   NaN        NaN           NaN
# 11                                   NaN        NaN           NaN
# 12                                   NaN        NaN           NaN
# 13                                   NaN        NaN           NaN
# 14                                   NaN        NaN           NaN
# 15  Region, subregion, country or area *      Notes  Country code
# 16                                 WORLD        NaN           900
# 17                 UN development groups          a          1803
# 18                More developed regions          b           901
# 19                Less developed regions          c           902
#
#            Unnamed: 5   Unnamed: 6  \
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4                 NaN          NaN
# 5                 NaN          NaN
# 6                 NaN          NaN
# 7                 NaN          NaN
# 8                 NaN          NaN
# 9                 NaN          NaN
# 10                NaN          NaN
# 11                NaN          NaN
# 12                NaN          NaN
# 13                NaN          NaN
# 14                NaN          NaN
# 15               Type  Parent code
# 16              World            0
# 17    Label/Separator          900
# 18  Development Group         1803
# 19  Development Group         1803
#
#                                            Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11                                                NaN         NaN         NaN
# 12                                                NaN         NaN         NaN
# 13                                                NaN         NaN         NaN
# 14  Total population, both sexes combined, as of 1...         NaN         NaN
# 15                                               1950        1951        1952
# 16                                          2 536 431   2 584 034   2 630 862
# 17                                                ...         ...         ...
# 18                                            814 819     824 004     833 720
# 19                                          1 721 612   1 760 031   1 797 142
#
#     ... Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72  \
# 0   ...         NaN         NaN         NaN         NaN         NaN
# 1   ...         NaN         NaN         NaN         NaN         NaN
# 2   ...         NaN         NaN         NaN         NaN         NaN
# 3   ...         NaN         NaN         NaN         NaN         NaN
# 4   ...         NaN         NaN         NaN         NaN         NaN
# 5   ...         NaN         NaN         NaN         NaN         NaN
# 6   ...         NaN         NaN         NaN         NaN         NaN
# 7   ...         NaN         NaN         NaN         NaN         NaN
# 8   ...         NaN         NaN         NaN         NaN         NaN
# 9   ...         NaN         NaN         NaN         NaN         NaN
# 10  ...         NaN         NaN         NaN         NaN         NaN
# 11  ...         NaN         NaN         NaN         NaN         NaN
# 12  ...         NaN         NaN         NaN         NaN         NaN
# 13  ...         NaN         NaN         NaN         NaN         NaN
# 14  ...         NaN         NaN         NaN         NaN         NaN
# 15  ...        2011        2012        2013        2014        2015
# 16  ...   7 041 194   7 125 828   7 210 582   7 295 291   7 379 797
# 17  ...         ...         ...         ...         ...         ...
# 18  ...   1 239 557   1 244 115   1 248 454   1 252 615   1 256 622
# 19  ...   5 801 637   5 881 713   5 962 129   6 042 676   6 123 175
#
#    Unnamed: 73 Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN
# 15        2016        2017        2018        2019        2020
# 16   7 464 022   7 547 859   7 631 091   7 713 468   7 794 799
# 17         ...         ...         ...         ...         ...
# 18   1 260 479   1 264 146   1 267 559   1 270 630   1 273 304
# 19   6 203 543   6 283 713   6 363 532   6 442 838   6 521 494
#
# [20 rows x 78 columns]

# %% [markdown]
# Slicing the dataframe from index 16 onwards and keeping the columns that correspond to country and the population as of 2020:

# %%
pop = pop[16:]
pop = pop.loc[:, ('Unnamed: 2', 'Unnamed: 77')]
pop
# Out:
#                     Unnamed: 2 Unnamed: 77
# 16                       WORLD   7 794 799
# 17       UN development groups         ...
# 18      More developed regions   1 273 304
# 19      Less developed regions   6 521 494
# 20   Least developed countries   1 057 438
# ..                         ...         ...
# 300                    Bermuda          62
# 301                     Canada      37 742
# 302                  Greenland          57
# 303  Saint Pierre and Miquelon           6
# 304   United States of America     331 003
#
# [289 rows x 2 columns]

# %% [markdown]
# Using `.rename()`, we are renaming the columns to `Country` and `Population`.
#
# Afterwards, we use `.reset_index()` and `.drop()` to reset the index:

# %%
pop.rename(
    columns = {'Unnamed: 2':'Country',
               'Unnamed: 77':'Population'},
    inplace = True
)
pop = pop.reset_index().drop(columns = ['index'])

# %%
pop
# Out:
#                        Country  Population
# 0                        WORLD   7 794 799
# 1        UN development groups         ...
# 2       More developed regions   1 273 304
# 3       Less developed regions   6 521 494
# 4    Least developed countries   1 057 438
# ..                         ...         ...
# 284                    Bermuda          62
# 285                     Canada      37 742
# 286                  Greenland          57
# 287  Saint Pierre and Miquelon           6
# 288   United States of America     331 003
#
# [289 rows x 2 columns]

# %% [markdown]
# ### Subset of Countries
#
# In this assignment, we need to work with a subset of data that includes
# - Indonesia,
# - Malaysia,
# - Singapore,
# - Thailand,
# - Philipines,
# - and Australia
#
# We put them into a list so that we can use it later on in conjunction with `.isin()`.

# %%
countries = ['Indonesia', 'Malaysia', 'Singapore', 'Thailand', 'Philippines', 'Australia']

# %% [markdown]
# Now, using `.isin` subset the data to only the countries that are needed:

# %%
vaccinations = vaccinations[vaccinations['Country'].isin(countries)]
gdp = gdp[gdp['Country'].isin(countries)]
pop = pop[pop['Country'].isin(countries)]

# %% [markdown]
# ## Merging datasets
#
# Using the `.merge()` command from **pandas**, we are combining the datasets together into one:

# %%
merged = pd.merge(vaccinations,gdp,on=['Country'])
merged = pd.merge(merged,pop,on=['Country'])

# %%
merged
# Out:
#        Country  People Fully Vaccinated  Total Vaccinations  \
# 0    Australia                4614203.0          13222783.0
# 1    Indonesia               24481296.0          72386296.0
# 2     Malaysia                9048634.0          23687251.0
# 3  Philippines               11614590.0          23230492.0
# 4    Singapore                3862510.0           7911869.0
# 5     Thailand                4277071.0          18349011.0
#
#                                   Vaccines Available          GDP Population
# 0                Oxford/AstraZeneca, Pfizer/BioNTech   1,330,901      25 500
# 1  Moderna, Oxford/AstraZeneca, Sinopharm/Beijing...   1,058,424     273 524
# 2       Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac     336,664      32 366
# 3  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...     361,489     109 581
# 4                           Moderna, Pfizer/BioNTech     339,998       5 850
# 5                        Oxford/AstraZeneca, Sinovac     501,795      69 800

# %% [markdown]
# ## Creating a new column 'perCapitaGDP'
#
# We are creating a new column called `perCapitaGDP` which is the GDP divided by population.
#
# First, we check the types of the columns:

# %%
merged.dtypes
# Out:
# Country                     object
# People Fully Vaccinated    float64
# Total Vaccinations         float64
# Vaccines Available          object
# GDP                         object
# Population                  object
# dtype: object

# %% [markdown]
# We can see that the data type for GDP and Population are objects. Therefore, we need to change the data type to numeric in order to divide GDP by Population.
#
# To do this, we need to replace ',' and blank spaces in `GDP` and `Population` in order to convert them into numeric data types:

# %%
merged['GDP'] = pd.to_numeric(
    merged['GDP'].str.replace(',', ''), errors='coerce')
merged['Population'] = pd.to_numeric(
    merged['Population'].str.replace(' ', ''), errors='coerce')

# %% [markdown]
# Then we proceed to create `perCapitaGDP`:

# %%
merged['perCapitaGDP'] = merged['GDP']/merged['Population']

# %%
merged
# Out:
#        Country  People Fully Vaccinated  Total Vaccinations  \
# 0    Australia                4614203.0          13222783.0
# 1    Indonesia               24481296.0          72386296.0
# 2     Malaysia                9048634.0          23687251.0
# 3  Philippines               11614590.0          23230492.0
# 4    Singapore                3862510.0           7911869.0
# 5     Thailand                4277071.0          18349011.0
#
#                                   Vaccines Available      GDP  Population  \
# 0                Oxford/AstraZeneca, Pfizer/BioNTech  1330901       25500
# 1  Moderna, Oxford/AstraZeneca, Sinopharm/Beijing...  1058424      273524
# 2       Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac   336664       32366
# 3  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...   361489      109581
# 4                           Moderna, Pfizer/BioNTech   339998        5850
# 5                        Oxford/AstraZeneca, Sinovac   501795       69800
#
#    perCapitaGDP
# 0     52.192196
# 1      3.869584
# 2     10.401780
# 3      3.298829
# 4     58.119316
# 5      7.189040

# %% [markdown]
# ## Statistical Description
#
# Looking at the data in `merged`, there are a few things that we can note:
# - Indonesia has the most total number of vaccinations among the countries,
# - Singapore has the most proportion of their population fully vaccinated at ~66%
# - The mean perCapitaGDP is 22.51 thousand USD
# - The mean GDP is 86,103.5 mil USD

# %% [markdown]
# # Question 1
#
# In order to visualise the estimated number of people vaccinated for each vaccine type, we could use a **pie graph** that shows the proportion of the population that is vaccinated for each vaccine type.
#
# If you wanted to compare the countries' populations, you could also use a segmented bar graph.
#
# First, we want to find the number of vaccines available to each country.

# %%
merged['Vaccines Available Count'] = merged['Vaccines Available'].str.count(',') + 1
merged
# Out:
#        Country  People Fully Vaccinated  Total Vaccinations  \
# 0    Australia                4614203.0          13222783.0
# 1    Indonesia               24481296.0          72386296.0
# 2     Malaysia                9048634.0          23687251.0
# 3  Philippines               11614590.0          23230492.0
# 4    Singapore                3862510.0           7911869.0
# 5     Thailand                4277071.0          18349011.0
#
#                                   Vaccines Available      GDP  Population  \
# 0                Oxford/AstraZeneca, Pfizer/BioNTech  1330901       25500
# 1  Moderna, Oxford/AstraZeneca, Sinopharm/Beijing...  1058424      273524
# 2       Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac   336664       32366
# 3  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...   361489      109581
# 4                           Moderna, Pfizer/BioNTech   339998        5850
# 5                        Oxford/AstraZeneca, Sinovac   501795       69800
#
#    perCapitaGDP  Vaccines Available Count
# 0     52.192196                         2
# 1      3.869584                         4
# 2     10.401780                         3
# 3      3.298829                         6
# 4     58.119316                         2
# 5      7.189040                         2

# %% [markdown]
# For a certain country (say the Philippines), we can find all the vaccines available and split them into a list using `.str.split(',')` and splitting where there are commas:

# %%
phil_vaccines = merged.loc[merged['Country'] == 'Philippines']['Vaccines Available'].str.split(',').item()
phil_vaccines
# Out:
# ['Johnson&Johnson',
#  ' Moderna',
#  ' Oxford/AstraZeneca',
#  ' Pfizer/BioNTech',
#  ' Sinovac',
#  ' Sputnik V']

# %% [markdown]
# Using basic python, we create a list of numbers that are split evenly into the number of vaccines available:

# %%
phil_vaccine_n = merged.loc[merged['Country']=='Philippines']['Vaccines Available Count'].item()
phil_vaccine_n
n_list = [1/phil_vaccine_n]*phil_vaccine_n

# %% [markdown]
# Lastly, we make the pie graph showing the number of people vaccinated per vaccine type if they were equally distributed to the country's population:

# %%
plt.pie(n_list, labels=phil_vaccines)
plt.title('People Vaccinated per Vaccine Type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# As one can see, the graph is straightforward as the vaccines have been distributed equally. Therefore, the population is approximately using each vaccine equally, creating an equal pie graph.

# %% [markdown]
# # Question 2
#
# For each country, we are going to plot a bar graph with side-by-side bars for `Population`, `Total Vaccinations`, and `People Fully Vaccinated`.
#
# Using `plt.bar` from the `matplotlib` library, we are creating three side by side bars for each country:

# %%
merged1 = merged.loc[:, ('Population', 'People Fully Vaccinated', 'Total Vaccinations')]
ax = merged1.plot.bar(figsize = (8,5))
ax.set_xticklabels(merged['Country'], rotation = 45)
plt.xlabel('Country')
plt.ylabel('Number of People')
plt.title('Vaccinations by Country')
plt.show()

# %% [markdown]
# As one can see, this graph does not make a good visualisation due to the large differences in numbers.
#
# In order to address the large differences in the population numbers, you can use segmented bar charts that show `Total Vaccinations` and `People Fully Vaccinated` as a proportion of the countries population.

# %%
percentfully = merged['People Fully Vaccinated']/(merged['Population']*1000)

barWidth = 0.5

plt.bar(merged['Country'], percentfully, width = barWidth, label = 'Fully Vaccinated')
plt.bar(merged['Country'], 1 - percentfully, bottom = percentfully, width = barWidth, label = ' Unvaccinated')

plt.xlabel('Country')
plt.ylabel('Proportion of Population')

plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
plt.title('Proportion of people fully vaccinated by population')

plt.show()

# %% [markdown]
# # Question 3
#
# To answer this question, we take the non-aggregated data from `Country-Vaccinations.csv` and read it into a new dataframe:

# %%
australia = pd.read_csv('data/Country-Vaccinations.csv')
australia.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %% [markdown]
# We subset the data for only Australia using `.loc`:

# %%
australia = australia.loc[australia['country'] == 'Australia']
australia
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 1746  Australia      AUS  2021-02-15                 0.0                0.0
# 1747  Australia      AUS  2021-02-16                 0.0                0.0
# 1748  Australia      AUS  2021-02-17                 0.0                0.0
# 1749  Australia      AUS  2021-02-18                 0.0                0.0
# 1750  Australia      AUS  2021-02-19                 0.0                0.0
# ...         ...      ...         ...                 ...                ...
# 1917  Australia      AUS  2021-08-05          13030257.0          8775905.0
# 1918  Australia      AUS  2021-08-06          13270296.0          8897750.0
# 1919  Australia      AUS  2021-08-07          13496355.0          9006750.0
# 1920  Australia      AUS  2021-08-08          13636580.0          9062787.0
# 1921  Australia      AUS  2021-08-09          13723146.0          9108943.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1746                      NaN                     NaN                 NaN
# 1747                      NaN                     0.0                 0.0
# 1748                      NaN                     0.0                 0.0
# 1749                      NaN                     0.0                 0.0
# 1750                      NaN                     0.0                 0.0
# ...                       ...                     ...                 ...
# 1917                4254352.0                221859.0            176432.0
# 1918                4372546.0                240039.0            180617.0
# 1919                4489605.0                226059.0            184239.0
# 1920                4573793.0                140225.0            188408.0
# 1921                4614203.0                 86566.0            189893.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1746                            0.00                           0.00
# 1747                            0.00                           0.00
# 1748                            0.00                           0.00
# 1749                            0.00                           0.00
# 1750                            0.00                           0.00
# ...                              ...                            ...
# 1917                           51.10                          34.42
# 1918                           52.04                          34.89
# 1919                           52.93                          35.32
# 1920                           53.48                          35.54
# 1921                           53.82                          35.72
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1746                                  NaN                             NaN
# 1747                                  NaN                             0.0
# 1748                                  NaN                             0.0
# 1749                                  NaN                             0.0
# 1750                                  NaN                             0.0
# ...                                   ...                             ...
# 1917                                16.68                          6919.0
# 1918                                17.15                          7083.0
# 1919                                17.61                          7225.0
# 1920                                17.94                          7389.0
# 1921                                18.09                          7447.0
#
#                                  vaccines  \
# 1746  Oxford/AstraZeneca, Pfizer/BioNTech
# 1747  Oxford/AstraZeneca, Pfizer/BioNTech
# 1748  Oxford/AstraZeneca, Pfizer/BioNTech
# 1749  Oxford/AstraZeneca, Pfizer/BioNTech
# 1750  Oxford/AstraZeneca, Pfizer/BioNTech
# ...                                   ...
# 1917  Oxford/AstraZeneca, Pfizer/BioNTech
# 1918  Oxford/AstraZeneca, Pfizer/BioNTech
# 1919  Oxford/AstraZeneca, Pfizer/BioNTech
# 1920  Oxford/AstraZeneca, Pfizer/BioNTech
# 1921  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                        source_name  \
# 1746  Government of Australia via covidlive.com.au
# 1747  Government of Australia via covidlive.com.au
# 1748  Government of Australia via covidlive.com.au
# 1749  Government of Australia via covidlive.com.au
# 1750  Government of Australia via covidlive.com.au
# ...                                            ...
# 1917  Government of Australia via covidlive.com.au
# 1918  Government of Australia via covidlive.com.au
# 1919  Government of Australia via covidlive.com.au
# 1920  Government of Australia via covidlive.com.au
# 1921  Government of Australia via covidlive.com.au
#
#                              source_website
# 1746  https://covidlive.com.au/vaccinations
# 1747  https://covidlive.com.au/vaccinations
# 1748  https://covidlive.com.au/vaccinations
# 1749  https://covidlive.com.au/vaccinations
# 1750  https://covidlive.com.au/vaccinations
# ...                                     ...
# 1917  https://covidlive.com.au/vaccinations
# 1918  https://covidlive.com.au/vaccinations
# 1919  https://covidlive.com.au/vaccinations
# 1920  https://covidlive.com.au/vaccinations
# 1921  https://covidlive.com.au/vaccinations
#
# [176 rows x 15 columns]

# %% [markdown]
# Using `.to_datatime()`, we are converting the `date` variable into datetime data type.
#
# We are also using the `.cumsum()` command to create a new column for the cumulative sum of daily vaccinations over time.

# %%
australia['date'] = pd.to_datetime(australia['date'])
australia['cum_sum'] = australia['daily_vaccinations'].cumsum()

# %% [markdown]
# Using `.plot` from the `pyplot` library, we are plotting daily vaccinations in Australia over time:

# %%
plt.plot(australia['date'], australia['daily_vaccinations'], label = 'Daily Vaccinations')

plt.xlabel('Date')
plt.ylabel('Number of Vaccinations')

plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
plt.title('Vaccinations in Australia')

plt.show()

# %% [markdown]
# Using `.plot`, we are plotting the cumulative daily vaccinations over time as well:

# %%
plt.plot(australia['date'], australia['cum_sum'], label = 'Cumulative Daily Vaccinations')

plt.xlabel('Date')
plt.ylabel('Number of Vaccinations')

plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
plt.title('Vaccinations in Australia')

plt.show()

# %% [markdown]
# The first graph could be used when they want to see how daily vaccinations are changing over time.
#
# The second graph would be used to display the total sum of daily vaccinations as it grows with time.
#
# The prime difference between the graphs is that the first graph would be changing over time dropping up and down, whilst the second graph only grows over time. Therefore, it is a better representation of how quickly the data is changing over time.
